# %%
import pandas as pd

# %%
data = pd.read_csv("~/Downloads/maml_trpo_17/progress.csv")

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Columns: 333 entries, push-v2/EpisodeMeanMaxInPlaceReward to basketball-v2/EpisodeMeanGraspReward
# dtypes: float64(297), int64(36)
# memory usage: 411.2 KB
# None

# %%
for col in data.columns:
    print(col)
# Out:
# push-v2/EpisodeMeanMaxInPlaceReward
# push-v2/TerminationRate
# MetaTest/lever-pull-v2/EpisodeMeanGraspReward
# button-press-topdown-v2/MinReward
# MetaTest/Average/MaxReward
# peg-insert-side-v2/AverageReturn
# sweep-v2/SuccessRate
# reach-v2/GraspSuccessRate
# MetaTest/sweep-into-v2/MaxReturn
# door-open-v2/NearObject
# window-open-v2/EpisodeMeanMaxInPlaceReward
# Average/NumEpisodes
# MetaTest/Average/NumEpisodes
# MetaTest/Average/SuccessRate
# push-v2/EpisodeMeanMinInPlaceReward
# Average/EpisodeMeanMinGraspReward
# MetaTest/door-close-v2/AverageDiscountedReturn
# MetaTest/drawer-open-v2/EpisodeMeanMaxInPlaceReward
# MetaTest/shelf-place-v2/NearObject
# MetaTest/shelf-place-v2/EpisodeMeanMinGraspReward
# MetaTest/door-close-v2/EpisodeMeanMinGraspReward
# basketball-v2/MinReturn
# MetaTest/Average/EpisodeMeanMaxGraspReward
# basketball-v2/EpisodeMeanMaxInPlaceReward
# reach-v2/MaxReturn
# MetaTest/Average/MaxReturn
# peg-insert-side-v2/EpisodeMeanMinGraspReward
# ...

# %%
data["Average/AverageReturn"].plot()
# Out:
# <AxesSubplot: >

# %%
data['Average/EpisodeMeanGraspReward'].plot()
# Out:
# <AxesSubplot: >

# %%
data['Average/SuccessRate'].plot()
# Out:
# <AxesSubplot: >

# %%
data['MetaTest/Average/SuccessRate'].plot()
# Out:
# <AxesSubplot: >

# %%
data['pick-place-v2/EpisodeMeanGraspReward'].plot()
# Out:
# <AxesSubplot: >
